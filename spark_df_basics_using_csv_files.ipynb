# %%
import findspark

# %%
findspark.init('/home/ubuntu/spark-2.4.0-bin-hadoop2.7/')

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('df_using_csv').getOrCreate()

# %%
df = spark.read.csv('appl_stock.csv',inferSchema=True,header=True)

# %%
df.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# ...

# %%
df.head(3)
# Out:
# [Row(Date=datetime.datetime(2010, 1, 4, 0, 0), Open=213.429998, High=214.499996, Low=212.38000099999996, Close=214.009998, Volume=123432400, Adj Close=27.727039),
#  Row(Date=datetime.datetime(2010, 1, 5, 0, 0), Open=214.599998, High=215.589994, Low=213.249994, Close=214.379993, Volume=150476200, Adj Close=27.774976000000002),
#  Row(Date=datetime.datetime(2010, 1, 6, 0, 0), Open=214.379993, High=215.23, Low=210.750004, Close=210.969995, Volume=138040000, Adj Close=27.333178000000004)]

# %%
df.filter("Close > 500").show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|        Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |2012-02-13 00:00:00|        499.529991|503.83000899999996|497.08998899999995|502.60002099999997|129304000|        65.116633|
# |2012-02-14 00:00:00|        504.659988|         509.56002|        502.000008|        509.459991|115099600|        66.005408|
# |2012-02-16 00:00:00|        491.500008|        504.890007|         486.62999|502.20999900000004|236138000|        65.066102|
# |2012-02-17 00:00:00|        503.109993|507.77002000000005|        500.299995|         502.12001|133951300|        65.054443|
# ...

# %%
df.filter(df['Close'] > 500).show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|        Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |2012-02-13 00:00:00|        499.529991|503.83000899999996|497.08998899999995|502.60002099999997|129304000|        65.116633|
# |2012-02-14 00:00:00|        504.659988|         509.56002|        502.000008|        509.459991|115099600|        66.005408|
# |2012-02-16 00:00:00|        491.500008|        504.890007|         486.62999|502.20999900000004|236138000|        65.066102|
# |2012-02-17 00:00:00|        503.109993|507.77002000000005|        500.299995|         502.12001|133951300|        65.054443|
# ...

# %%
df.filter( (df['Close']>500) & (df['Open']>500) ).show()
# Out:
# +-------------------+------------------+------------------+------------------+-----------------+---------+-----------------+
# |               Date|              Open|              High|               Low|            Close|   Volume|        Adj Close|
# +-------------------+------------------+------------------+------------------+-----------------+---------+-----------------+
# |2012-02-14 00:00:00|        504.659988|         509.56002|        502.000008|       509.459991|115099600|        66.005408|
# |2012-02-17 00:00:00|        503.109993|507.77002000000005|        500.299995|        502.12001|133951300|        65.054443|
# |2012-02-21 00:00:00|506.88001299999996|        514.850021|504.12000300000005|       514.850021|151398800|        66.703738|
# |2012-02-22 00:00:00|        513.079994|        515.489983|509.07002300000005|       513.039993|120825600|66.46923100000001|
# ...

# %%
df.filter( (df['Close']>500) & ~(df['Open']>500) ).show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|        Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+-----------------+
# |2012-02-13 00:00:00|        499.529991|503.83000899999996|497.08998899999995|502.60002099999997|129304000|        65.116633|
# |2012-02-16 00:00:00|        491.500008|        504.890007|         486.62999|502.20999900000004|236138000|        65.066102|
# |2013-01-16 00:00:00|494.63999900000005|509.44001799999995|492.49997699999994|506.08998099999997|172701200|        66.151072|
# |2013-01-18 00:00:00|        498.519981|        502.219986|        496.399986|        500.000015|118230700|        65.355052|
# ...

# %%
df.filter(df['Low'] == 496.399).show()
# Out:
# +----+----+----+---+-----+------+---------+
# |Date|Open|High|Low|Close|Volume|Adj Close|
# +----+----+----+---+-----+------+---------+
# +----+----+----+---+-----+------+---------+

# %%
df.filter(df['Low'] == 496.399986).show()
# Out:
# +-------------------+----------+----------+----------+----------+---------+---------+
# |               Date|      Open|      High|       Low|     Close|   Volume|Adj Close|
# +-------------------+----------+----------+----------+----------+---------+---------+
# |2013-01-18 00:00:00|498.519981|502.219986|496.399986|500.000015|118230700|65.355052|
# +-------------------+----------+----------+----------+----------+---------+---------+

# %%
df.filter(df['Low'] == 197.16).collect()
# Out:
# [Row(Date=datetime.datetime(2010, 1, 22, 0, 0), Open=206.78000600000001, High=207.499996, Low=197.16, Close=197.75, Volume=220441900, Adj Close=25.620401)]

# %%
result = df.filter(df['Close'] > 500).collect()

# %%
result
# Out:
# [Row(Date=datetime.datetime(2012, 2, 13, 0, 0), Open=499.529991, High=503.83000899999996, Low=497.08998899999995, Close=502.60002099999997, Volume=129304000, Adj Close=65.116633),
#  Row(Date=datetime.datetime(2012, 2, 14, 0, 0), Open=504.659988, High=509.56002, Low=502.000008, Close=509.459991, Volume=115099600, Adj Close=66.005408),
#  Row(Date=datetime.datetime(2012, 2, 16, 0, 0), Open=491.500008, High=504.890007, Low=486.62999, Close=502.20999900000004, Volume=236138000, Adj Close=65.066102),
#  Row(Date=datetime.datetime(2012, 2, 17, 0, 0), Open=503.109993, High=507.77002000000005, Low=500.299995, Close=502.12001, Volume=133951300, Adj Close=65.054443),
#  Row(Date=datetime.datetime(2012, 2, 21, 0, 0), Open=506.88001299999996, High=514.850021, Low=504.12000300000005, Close=514.850021, Volume=151398800, Adj Close=66.703738),
# ...

# %%
result[0]
# Out:
# Row(Date=datetime.datetime(2012, 2, 13, 0, 0), Open=499.529991, High=503.83000899999996, Low=497.08998899999995, Close=502.60002099999997, Volume=129304000, Adj Close=65.116633)

# %%
row = result[0]

# %%
row.asDict()
# Out:
# {'Date': datetime.datetime(2012, 2, 13, 0, 0),
#  'Open': 499.529991,
#  'High': 503.83000899999996,
#  'Low': 497.08998899999995,
#  'Close': 502.60002099999997,
#  'Volume': 129304000,
#  'Adj Close': 65.116633}

# %%
row.asDict()['Volume']
# Out:
# 129304000
